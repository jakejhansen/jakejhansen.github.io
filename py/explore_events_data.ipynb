# %% [markdown]
# # Imports

# %%
import functools
import os
import gzip
import pandas as pd

import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (20, 10)

# %% [markdown]
# # Read data to df

# %%
df = pd.read_csv(gzip.open(os.path.join('data', 'events.csv.gz')),
                 delimiter='|', parse_dates=['start_time'])
df.head()
# Out:
# /home/inonpe/jupyter/dtu_visualization_d3_course/project/py/env/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,26,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    id    source          start_time end_time   latitude  \
# 0  E0-001-094943257-4  eventful 2016-08-19 19:00:00      NaN  40.700800
# 1  E0-001-094206304-7  eventful 2016-08-27 21:00:00      NaN  40.721321
# 2  E0-001-092628830-9  eventful 2016-07-15 20:00:00      NaN  40.719288
# 3  E0-001-093348618-5  eventful 2016-06-28 18:00:00      NaN  40.668600
# 4  E0-001-095381670-0  eventful 2016-08-08 19:00:00      NaN  40.742716
#
#    longitude postal_code  all_day  free  featured     ...       \
# 0 -73.713300         NaN      0.0   NaN       NaN     ...
# 1 -73.988212       10002      0.0   NaN       NaN     ...
# 2 -73.961708       11211      0.0   NaN       NaN     ...
# 3 -74.114700         NaN      0.0   NaN       NaN     ...
# 4 -73.992934         NaN      0.0   NaN       NaN     ...
#
#                          venue_escaped  address_escaped  \
# 0                            NuSpecies              NaN
# 1                     Arlene's Grocery              NaN
# 2           Music Hall of Williamsburg              NaN
# 3  Dorothy Harrington Council Chambers              NaN
# 4                      3 Sheets Saloon              NaN
#
#                                  description_escaped  \
# 0   In this workshop, Beverley Leon, one of NuSpe...
# 1                                              <br>
# 2                                                NaN
# 3                                                NaN
# 4   Join us for the 4th year of helping kids who ...
#
#                                   categories_escaped  tags_escaped  \
# 0  {u'category': [{u'name': u'Health &amp; Wellne...           NaN
# 1  {u'category': [{u'name': u'Other &amp; Miscell...           NaN
# 2  {u'category': [{u'name': u'Concerts &amp; Tour...           NaN
# 3  {u'category': [{u'name': u'Neighborhood', u'id...           NaN
# 4  {u'category': [{u'name': u'Fundraising &amp; C...           NaN
#
#    recurrent_escaped                                 performers_escaped  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN  {u'performer': {u'name': u'Emily King', u'crea...
# 3                NaN                                                NaN
# 4                NaN                                                NaN
#
#     price_escaped                                        url_escaped  \
# 0             NaN  http://newyorkcity.eventful.com/events/digesti...
# 1          $10.00  http://newyorkcity.eventful.com/events/disconn...
# 2  25.00 - 25.00   http://newyorkcity.eventful.com/events/emily-k...
# 3             NaN  http://newyorkcity.eventful.com/events/cancell...
# 4             NaN  http://newyorkcity.eventful.com/events/operati...
#
#   city_escaped
# 0       Elmont
# 1     New York
# 2     Brooklyn
# 3      Bayonne
# 4     New York
#
# [5 rows x 33 columns]

# %%
# Top 10 busiest venues.
df.venue_escaped.value_counts().head(10)
# Out:
# Rockwood Music Hall             896
# B.B. King Blues Club & Grill    873
# The Bowery Electric             623
# Mercury Lounge                  548
# C'mon Everybody                 537
# Webster Hall                    535
# Jazz Standard                   496
# Brooklyn Bowl                   465
# The Leonora                     464
# (le) poisson rouge              432
# Name: venue_escaped, dtype: int64

# %%
df.venue_escaped.value_counts()
# Out:
# Rockwood Music Hall                                       896
# B.B. King Blues Club & Grill                              873
# The Bowery Electric                                       623
# Mercury Lounge                                            548
# C'mon Everybody                                           537
# Webster Hall                                              535
# Jazz Standard                                             496
# Brooklyn Bowl                                             465
# The Leonora                                               464
# (le) poisson rouge                                        432
# New York, NY                                              412
# PIANOS                                                    411
# DROM                                                      401
# SOB's (Sounds of Brazil)                                  365
# Highline Ballroom                                         360
# Muchmore's                                                358
# City Winery NYC                                           350
# Output                                                    345
# Trans-Pecos                                               344
# Madison Square Garden                                     335
# Cielo                                                     335
# Baby's All Right                                          334
# Knitting Factory Brooklyn                                 322
# The Silent Barn                                           320
# Palisades                                                 318
# New York, NY, United States                               316
# Bossa Nova Civic Club                                     304
# Arlene's Grocery                                          298
# The Grand Victory                                         296
# Rough Trade NYC                                           282
#                                                          ...
# Pier 62, Chelsea Piers, New York                            1
# Hudson Pier 26                                              1
# Gnocco                                                      1
# Insa                                                        1
# Luvas Theatre Company                                       1
# 239 South Avenue                                            1
# The Funky OM 400                                            1
# Popeis Clam Bar                                             1
# Popeyes                                                     1
# Time Equities, Inc. Art-in-Buildings Program                1
# Tilila Casa Publica y Cocina                                1
# Carroll Gardens CSA                                         1
# Brooklyn Terrace                                            1
# Adam Clayton Powell Jr State Office Bldg                    1
# Max Bridal NY                                               1
# Lincoln Center - Claire Tow Theater                         1
# Concepts NYC                                                1
# NVC 5-165                                                   1
# York College, City University of New York                   1
# East Coast Starz                                            1
# Wollman Hall, Eugene Lang College, 65 West 11th Street      1
# 95 Rivington                                                1
# Leota New York                                              1
# GoStride                                                    1
# Ryan's Daughter                                             1
# "The Klub 45 Room" at Connolly's Times Square               1
# MICROSCOPE GALLERY                                          1
# Flagship Brewing Company                                    1
# Break Bar and Billiards                                     1
# Mamma Vittoria Restaurant                                   1
# Name: venue_escaped, Length: 18296, dtype: int64

# %%
df.start_time.min(), df.start_time.max()
# Out:
# (Timestamp('2015-09-12 16:00:00'), Timestamp('2017-02-26 00:00:00'))

# %% [markdown]
# # Some timelines of venues

# %%
def plot_timeline(venue_name):
    df\
        [df.venue_escaped == venue_name]\
        [['start_time']]\
        .assign(hr=lambda df: df.start_time.dt.hour)\
        .set_index('start_time')\
        .plot()

# %%
plot_timeline('B.B. King Blues Club & Grill')

# %%
plot_timeline('Rockwood Music Hall')

# %%
plot_timeline('Madison Square Garden')

# %% [markdown]
# # Venues for which we have Dropoffs

# %%
venues = [
    'barclays_center',
    'beacon_theatre',
    'bowery_ballroom',
    'carnegie_hall',
    'javits',
    'lincoln_center',
    'madison_square_garden',
    'moma',
    'music_hall_of_williamsburg',
    'playstation_theater',
    'radio_city_music_hall',
    'terminal_5',
    'the_town_hall'
]

# %%
for v in venues:
    vname = v.replace('_', ' ')
    print(vname, len(df[df.venue_escaped.str.lower().str.contains(vname).astype(bool)].venue_escaped.dropna()))
# Out:
# barclays center 204
# beacon theatre 196
# bowery ballroom 282
# carnegie hall 79
# javits 128
# lincoln center 251
# madison square garden 380
# moma 158
# music hall of williamsburg 165
# playstation theater 74
# radio city music hall 264
# terminal 5 179
# the town hall 78

# %%
df[df.venue_escaped.str.lower().str.contains('moma').astype(bool)].venue_escaped.dropna()
# Out:
# 5038                                 MoMA PS1
# 6837                                 MoMA PS1
# 9518                                 MoMA PS1
# 9809                                 MoMA PS1
# 11599                                MoMA PS1
# 11630                                MoMA PS1
# 14079                                MoMA PS1
# 15439                                MoMA PS1
# 17640                                MoMA PS1
# 19561                                MoMA PS1
# 19572                                MoMA PS1
# 20108           MoMA The Museum of Modern Art
# 23087                                MoMA PS1
# 24745                                MoMA PS1
# 27584                                MoMA PS1
# 29737                                MoMA PS1
# 29794                                MoMA PS1
# 30270           MoMA The Museum of Modern Art
# 30660                     Artbook at MoMA PS1
# 30803                                MoMA PS1
# 31458                                MoMA PS1
# 32038                                MoMA PS1
# 33138                     Artbook at MoMA PS1
# 34808                                MoMA PS1
# 34869                                MoMA PS1
# 34871                                MoMA PS1
# 34872                                MoMA PS1
# 34873                                MoMA PS1
# 34874                                MoMA PS1
# 34958                                MoMA PS1
#                          ...
# 81626                                MoMA PS1
# 82223                                MoMA PS1
# 83260           MoMA The Museum of Modern Art
# 83398                                MoMA PS1
# 84321                                MoMA PS1
# 85229           MoMA The Museum of Modern Art
# 85834           MoMA The Museum of Modern Art
# 87233                                MoMA PS1
# 91213                                MoMA PS1
# 91673                                MoMA PS1
# 92209           MoMA The Museum of Modern Art
# 92709           MoMA The Museum of Modern Art
# 92914                                MoMA PS1
# 94319           MoMA The Museum of Modern Art
# 94430           MoMA The Museum of Modern Art
# 95042           MoMA The Museum of Modern Art
# 95045           MoMA The Museum of Modern Art
# 100178                               MoMA PS1
# 100547          MoMA The Museum of Modern Art
# 100610                               MoMA PS1
# 101318                               MoMA PS1
# 101461                    Artbook at MoMA PS1
# 102198          MoMA The Museum of Modern Art
# 102240          MoMA The Museum of Modern Art
# 106158                               MoMA PS1
# 108198                               MoMA PS1
# 109214                               MoMA PS1
# 111877                               MoMA PS1
# 112291                               MoMA PS1
# 115129    Classroom space one block from MoMA
# Name: venue_escaped, Length: 158, dtype: object

# %% [markdown]
# # Event Categories

# %%
c = [eval(e) for e in df.categories_escaped.dropna()]

# %%
l1 = functools.reduce(lambda l1, l2: l1 + l2, map(lambda lst: [e.lower() for e in lst], filter(lambda e: type(e) == list, c)))

# %%
l2 = []
for ctg in map(lambda e: e['category'], filter(lambda e: type(e) == dict, c)):
    try:
        l2.extend(ctg)
    except TypeError:
        pass
l2 = list(map(lambda e: e['id'], l2))

# %%
l = l1 + l2

# %%
import collections
sorted(collections.Counter(l).items(), key=lambda pair: -pair[1])
# Out:
# [('music', 5891),
#  ('other', 5623),
#  ('performing_arts', 3167),
#  ('community', 2692),
#  ('singles_social', 2419),
#  ('family_fun_kids', 2077),
#  ('food', 1414),
#  ('outdoors_recreation', 1402),
#  ('sports', 1293),
#  ('business', 1246),
#  ('movies_film', 1119),
#  ('support', 1058),
#  ('fundraisers', 838),
#  ('art', 705),
#  ('learning_education', 649),
#  ('comedy', 636),
#  ('attractions', 603),
#  ('festivals_parades', 562),
#  ('books', 535),
#  ('schools_alumni', 510),
#  ('holiday', 395),
#  ('science', 317),
#  ('conference', 292),
#  ('technology', 270),
#  ('religion_spirituality', 183),
#  ('politics_activism', 143),
#  ('clubs_associations', 126),
#  ('entertainment', 92),
#  ('sales', 86),
#  ('animals', 64),
#  ('concerts', 50),
#  ('friendship-day', 47),
#  ('workshops', 20),
#  ('parties', 20),
#  ('theatre', 15),
#  ('performances', 11),
#  ('literary-art', 10),
#  ('trips-adventures', 9),
#  ('festivals', 9),
#  ('meetups', 8),
#  ('dance', 7),
#  ('health-wellness', 5),
#  ('food-drinks', 4),
#  ('cooking', 2),
#  ('fine-arts', 1),
#  ('exhibitions', 1)]

# %% [markdown]
# # Data for D3

# %%
cols = ['id', 'source', 'start_time', 'latitude', 'longitude', 'venue_escaped']
for v in venues:
    vname = v.replace('_', ' ')
    selected = df.iloc[df[df.venue_escaped.str.lower().str.contains(vname).astype(bool)].venue_escaped.dropna().index][cols]
    selected.to_csv(os.path.join('for_d3', vname.replace(' ', '_') + '.csv'), index=False)

# %%
def daily_activity(venue_name):
    return df[df.venue_escaped.str.lower().str.contains(venue_name.lower()).astype(bool)]\
        [['start_time']]\
        .assign(day=lambda df: df.start_time.dt.date)\
        .groupby('day') \
        .count()\
        .sort_index()\
        .rename(columns={'start_time': 'daily_total'})\
        .assign(venue=venue_name)

with open(os.path.join('for_d3', 'daily_event_count.csv'), 'w') as f:
    f.write('day,daily_total,venue\n')
    for v in venues:
        vname = v.replace('_', ' ')
        daily_activity(vname).to_csv(f, header=False)
        
daily_activity('Madison Square Garden').head()
# Out:
#             daily_total                  venue
# day
# 2015-09-18            3  Madison Square Garden
# 2015-09-19            1  Madison Square Garden
# 2015-09-22            1  Madison Square Garden
# 2015-09-24            1  Madison Square Garden
# 2015-09-25            1  Madison Square Garden

# %%
def hourly_activity(venue_name):
    return df[df.venue_escaped.str.lower().str.contains(venue_name).astype(bool)]\
        [['start_time']]\
        .assign(hour=lambda df: df.start_time.dt.hour)\
        .groupby('hour') \
        .count()\
        .sort_index()

def hourly_all_venues():
    for v in venues:
        vname = v.replace('_', ' ')
        df_v = hourly_activity(vname)
        counts = []
        print(vname)
        for hour in range(24):
            try:
                counts.append(df_v.loc[hour][0])
            except KeyError:
                counts.append(0)
        with open(os.path.join('for_d3', 'hourly_event_count_' + v + '.csv'), 'w') as f:
            f.write(','.join(map(str, counts)) + '\n')
        
# hourly_activity('Madison Square Garden').iloc[0][0]
hourly_all_venues()
# Out:
# barclays center
# beacon theatre
# bowery ballroom
# carnegie hall
# javits
# lincoln center
# madison square garden
# moma
# music hall of williamsburg
# playstation theater
# radio city music hall
# terminal 5
# the town hall

# %%
 df[df.venue_escaped == 'Madison Square Garden'].sort_values(by='start_time')
# Out:
#                                                                 48435   \
# id                                                            29403736
# source                                                    timeoutworld
# start_time                                         2015-09-19 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                           1
# count_attending                                                    220
# count_not_replied                                                   58
# count_unsure                                                        14
# count_declined                                                      24
# vote_score                                                           2
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                             Daddy Yankee
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 101524  \
# id                                                            26982334
# source                                                    timeoutworld
# start_time                                         2015-09-26 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                           9
# count_attending                                                    175
# count_not_replied                                                   12
# count_unsure                                                        16
# count_declined                                                      38
# vote_score                                                           4
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                  Billy Joel - In Concert
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 34099   \
# id                                                            29732569
# source                                                    timeoutworld
# start_time                                         2015-09-26 20:30:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                           3
# count_attending                                                     10
# count_not_replied                                                    0
# count_unsure                                                         1
# count_declined                                                       0
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped        BILLY JOEL\tMadison Square Garden  Sat, Sep 26...
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped  In 2015, Billy Joel will be established as the...
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 47025   \
# id                                                            29870043
# source                                                    timeoutworld
# start_time                                         2015-10-01 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                           8
# count_attending                                                      9
# count_not_replied                                                    0
# count_unsure                                                         0
# count_declined                                                       1
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                      STROMAE LIVE AT MSG
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped  Stromae\nWith special guest Janelle Monáe\nOct...
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 27770   \
# id                                                            26894281
# source                                                    timeoutworld
# start_time                                         2015-10-01 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                          12
# count_attending                                                   1293
# count_not_replied                                                  199
# count_unsure                                                        73
# count_declined                                                     171
# vote_score                                                           4
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                                  Stromae
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 26253   \
# id                                                            29647899
# source                                                    timeoutworld
# start_time                                         2015-10-02 20:00:00
# end_time                                           2015-10-03 01:00:00
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                          21
# count_attending                                                    242
# count_not_replied                                                 1489
# count_unsure                                                        21
# count_declined                                                     130
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped            ZEDD - MADISON SQUARE GARDEN - ONE WORLD TOUR
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped  With production credits for Lady Gaga and a pe...
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 28931   \
# id                                                            28890671
# source                                                    timeoutworld
# start_time                                         2015-10-02 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                          22
# count_attending                                                    602
# count_not_replied                                                   80
# count_unsure                                                        31
# count_declined                                                      49
# vote_score                                                           2
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped            Zedd - True Colors Tour Presented By T-Mobile
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 25450   \
# id                                                            29901698
# source                                                    timeoutworld
# start_time                                         2015-10-02 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                          14
# count_attending                                                     15
# count_not_replied                                                  476
# count_unsure                                                         2
# count_declined                                                      16
# vote_score                                                           3
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped        Zedd, Madeon, Alunageorge, Alex Metric at Madi...
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped  Friday, October 2nd\n\nZedd True Colors Tour w...
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 45507   \
# id                                                            29856256
# source                                                    timeoutworld
# start_time                                         2015-10-02 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                          14
# count_attending                                                      8
# count_not_replied                                                    1
# count_unsure                                                         1
# count_declined                                                       0
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped        Zedd True Colors Tour with Madeon <> Aluna Geo...
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped  Zedd\nTrue Colors Tour\nwith\nMadeon\nAluna Ge...
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 25178   \
# id                                                            29862519
# source                                                    timeoutworld
# start_time                                         2015-10-03 19:30:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                          19
# count_attending                                                      8
# count_not_replied                                                    0
# count_unsure                                                         1
# count_declined                                                       0
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E6100000F6B02DD0897F52C00A9F8C4C1160...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                        WWE: Live - Madison Square Garden
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped  WWE: Live \tMadison Square Garden\n\nNew York,...
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                            ...                          \
# id                                         ...
# source                                     ...
# start_time                                 ...
# end_time                                   ...
# latitude                                   ...
# longitude                                  ...
# postal_code                                ...
# all_day                                    ...
# free                                       ...
# featured                                   ...
# watching_count                             ...
# comment_count                              ...
# view_count                                 ...
# count_attending                            ...
# count_not_replied                          ...
# count_unsure                               ...
# count_declined                             ...
# vote_score                                 ...
# score                                      ...
# location                                   ...
# location_zone                              ...
# location_tract                             ...
# title_escaped                              ...
# venue_escaped                              ...
# address_escaped                            ...
# description_escaped                        ...
# categories_escaped                         ...
# tags_escaped                               ...
# recurrent_escaped                          ...
# performers_escaped                         ...
# price_escaped                              ...
# url_escaped                                ...
# city_escaped                               ...
#
#                                                                 105899  \
# id                                                  E0-001-094405626-3
# source                                                        eventful
# start_time                                         2016-08-11 19:30:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9934
# postal_code                                                      10001
# all_day                                                              0
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                         NaN
# count_attending                                                    NaN
# count_not_replied                                                  NaN
# count_unsure                                                       NaN
# count_declined                                                     NaN
# vote_score                                                         NaN
# score                                                              NaN
# location             0101000020E6100000A9177CF4937F52C0B22688BA0F60...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                   TWENTY ØNE PILØTS - EMØTIØNAL RØADSHØW
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped   {u'category': [{u'name': u'Concerts &amp; Tour...
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped          http://newyorkcity.eventful.com/events/twenty-...
# city_escaped                                                  New York
#
#                                                                 112444  \
# id                                                  E0-001-088615844-9
# source                                                        eventful
# start_time                                         2016-08-11 19:30:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9934
# postal_code                                                      10001
# all_day                                                              0
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                         NaN
# count_attending                                                    NaN
# count_not_replied                                                  NaN
# count_unsure                                                       NaN
# count_declined                                                     NaN
# vote_score                                                         NaN
# score                                                              NaN
# location             0101000020E6100000A9177CF4937F52C0B22688BA0F60...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                        Twenty One Pilots
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped   {u'category': [{u'name': u'Concerts &amp; Tour...
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped   {u'performer': {u'name': u'Twenty One Pilots',...
# price_escaped                                                      NaN
# url_escaped          http://newyorkcity.eventful.com/events/twenty-...
# city_escaped                                                  New York
#
#                                                                 108672  \
# id                                                  E0-001-094769684-0
# source                                                        eventful
# start_time                                         2016-08-13 19:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9934
# postal_code                                                      10001
# all_day                                                              0
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                         NaN
# count_attending                                                    NaN
# count_not_replied                                                  NaN
# count_unsure                                                       NaN
# count_declined                                                     NaN
# vote_score                                                         NaN
# score                                                              NaN
# location             0101000020E6100000A9177CF4937F52C0B22688BA0F60...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                   Food festival at Madison Square Garden
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                     Food festival
# categories_escaped   {u'category': [{u'name': u'Festivals', u'id': ...
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped          http://newyorkcity.eventful.com/events/food-fe...
# city_escaped                                                  New York
#
#                                                                 52904   \
# id                                                            30092019
# source                                                    timeoutworld
# start_time                                         2016-08-13 19:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9929
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                           5
# count_attending                                                     33
# count_not_replied                                                   26
# count_unsure                                                        19
# count_declined                                                       1
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E6100000A9623C918B7F52C06B8FF2D31060...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                    Halsey: Badlands Tour
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped  Price:\r\n$ 34.50 - $ 54.50\r\n\r\nAge Limit:\...
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                       NaN
#
#                                                                 49104   \
# id                                                            32385394
# source                                                    timeoutworld
# start_time                                         2016-08-13 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9929
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                           5
# count_attending                                                     23
# count_not_replied                                                    7
# count_unsure                                                        78
# count_declined                                                       0
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E6100000A9623C918B7F52C06B8FF2D31060...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                                   Halsey
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped  Get your Tickets to see Halsey here - http://w...
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                  New York
#
#                                                                 12965   \
# id                                                  E0-001-088354933-0
# source                                                        eventful
# start_time                                         2016-08-13 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9934
# postal_code                                                      10001
# all_day                                                              0
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                         NaN
# count_attending                                                    NaN
# count_not_replied                                                  NaN
# count_unsure                                                       NaN
# count_declined                                                     NaN
# vote_score                                                         NaN
# score                                                              NaN
# location             0101000020E6100000A9177CF4937F52C0B22688BA0F60...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                                   Halsey
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped   {u'category': [{u'name': u'Concerts &amp; Tour...
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                           34.50 - 54.50
# url_escaped          http://newyorkcity.eventful.com/events/halsey-...
# city_escaped                                                  New York
#
#                                                                 55052   \
# id                                                            30187568
# source                                                    timeoutworld
# start_time                                         2016-08-13 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7506
# longitude                                                     -73.9928
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                           6
# count_attending                                                    614
# count_not_replied                                                  770
# count_unsure                                                       529
# count_declined                                                      23
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E61000001DDDBC94897F52C019BAB6C11260...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                   Halsey - Badlands Tour
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                             Halsey - Badlands Tour
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                  New York
#
#                                                                 13410   \
# id                                                  E0-001-095905406-5
# source                                                        eventful
# start_time                                         2016-08-21 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9934
# postal_code                                                      10001
# all_day                                                              0
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                         NaN
# count_attending                                                    NaN
# count_not_replied                                                  NaN
# count_unsure                                                       NaN
# count_declined                                                     NaN
# vote_score                                                         NaN
# score                                                              NaN
# location             0101000020E6100000A9177CF4937F52C0B22688BA0F60...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                   The Kingdom: Daddy Yankee vs. Don Omar
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped   {u'category': [{u'name': u'Concerts &amp; Tour...
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped          http://newyorkcity.eventful.com/events/kingdom...
# city_escaped                                                  New York
#
#                                                                 14721   \
# id                                                            33214560
# source                                                    timeoutworld
# start_time                                         2016-08-21 20:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9929
# postal_code                                                        NaN
# all_day                                                            NaN
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                           0
# count_attending                                                    164
# count_not_replied                                                   94
# count_unsure                                                       441
# count_declined                                                      11
# vote_score                                                           0
# score                                                              NaN
# location             0101000020E6100000A9623C918B7F52C06B8FF2D31060...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                   The Kingdom: Daddy Yankee vs. Don Omar
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped             The Kingdom: Daddy Yankee vs. Don Omar
# categories_escaped                                                 NaN
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped                                                        NaN
# city_escaped                                                  New York
#
#                                                                 110583
# id                                                  E0-001-095785417-9
# source                                                        eventful
# start_time                                         2016-08-28 21:00:00
# end_time                                                           NaN
# latitude                                                       40.7505
# longitude                                                     -73.9934
# postal_code                                                      10001
# all_day                                                              0
# free                                                               NaN
# featured                                                           NaN
# watching_count                                                     NaN
# comment_count                                                      NaN
# view_count                                                         NaN
# count_attending                                                    NaN
# count_not_replied                                                  NaN
# count_unsure                                                       NaN
# count_declined                                                     NaN
# vote_score                                                         NaN
# score                                                              NaN
# location             0101000020E6100000A9177CF4937F52C0B22688BA0F60...
# location_zone                                                       15
# location_tract                                                     727
# title_escaped                                  2016 Video Music Awards
# venue_escaped                                    Madison Square Garden
# address_escaped                                                    NaN
# description_escaped                                                NaN
# categories_escaped   {u'category': [{u'name': u'Performing Arts', u...
# tags_escaped                                                       NaN
# recurrent_escaped                                                  NaN
# performers_escaped                                                 NaN
# price_escaped                                                      NaN
# url_escaped          http://newyorkcity.eventful.com/events/2016-vi...
# city_escaped                                                  New York
#
# [33 rows x 335 columns]
